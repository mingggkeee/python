# %%
from urllib import request

# d = request.urlopen('http://www.daum.net')
d = request.urlopen('http://developers.google.com')
d.read().decode('utf-8')
# Out:
# mes, & Insights podcast"\n        class="hide-from-toc no-link"\n        tabindex="0">\n      \n  <a href="https://developer.android.com/podcasts/apps-games-insights?utm_source=GoogleDevelopers&amp;utm_medium=Website&amp;utm_campaign=podcastseries2&amp;utm_content=Generic"\n      \n        data-category="Homepage Promo Banner"\n      \n        data-label="Apps Games Insights, Main title"\n      \n        data-action="link"\n      \n    >\n    \n        New episodes: Apps, Games, & Insights podcast\n      \n  </a>\n  \n    </h3>\n  \n\n        \n          <div class="devsite-landing-row-item-description-content">\n            Tune in for the second series for new insights from Google and experts on topics like app-based learning, "green" games, inclusivity, improving app quality with Firebase, and multi-platform games.\n\n          </div>\n        \n\n        \n\n        \n          <div class="devsite-landing-row-item-buttons">\n  \n\n  \n  <a href="https://developer.android.com/podcasts/apps-games-insights?utm_source=GoogleDevelopers&amp;utm_medium=Website&amp;utm_campaign=podcastseries2&amp;utm_content=Generic"\n  \n    \n      class="button\n             button-white\n             "\n    \n    \n      \n        data-label="Apps Games Insights, Learn more"\n      \n        data-action="button"\n      \n        data-category="Homepage Promo Banner"\n      \n    \n    >Learn more</a>\n\n</div>\n        \n      </div>\n    </div>\n    \n  \n\n</div>\n        \n        </div>\n      \n\n    \n    </div>\n  </section>\n\n    \n\n    \n  </div>\n\n  \n\n  \n\n  \n  \n</article>\n\n\n\n\n            \n          </devsite-content>\n        </main>\n        <devsite-footer-promos class="devsite-footer">\n          \n            \n          \n        </devsite-footer-promos>\n        <devsite-footer-linkboxes class="devsite-footer">\n          \n            \n<nav class="devsite-footer-linkboxes nocontent" aria-label="Footer links">\n  \n  <ul class="devsite-footer-linkboxes-list">\n    \n    <li class="devsite-footer-linkbox ">\n    <h3 class="devsite-footer-linkbox-heading no-link">Connect</h3>\n      <ul class="devsite-footer-linkbox-list">\n        \n        <li class="devsite-footer-linkbox-item">\n          \n          <a href="//googledevelopers.blogspot.com"\n             class="devsite-footer-linkbox-link gc-analytics-event"\n             data-category="Site-Wide Custom Events"\n            \n             data-label="Footer Link (index 1)"\n            >\n          \n            Blog\n          \n          </a>\n          \n        </li>\n        \n        <li class="devsite-footer-linkbox-item">\n          \n          <a href="//www.facebook.com/Google-Developers-967415219957038"\n             class="devsite-footer-linkbox-link gc-analytics-event"\n             data-category="Site-Wide Custom Events"\n            \n             data-label="Footer Link (index 2)"\n            >\n          \n            Facebook\n          \n          </a>\n          \n        </li>\n        \n        <li class="devsite-footer-linkbox-item">\n          \n          <a href="//medium.com/google-developers"\n             class="devsite-footer-linkbox-link gc-analytics-event"\n             data-category="Site-Wide Custom Events"\n            \n             data-label="Footer Link (index 3)"\n            >\n          \n            Medium\n          \n          </a>\n          \n        </li>\n        \n        <li class="devsite-footer-linkbox-item">\n          \n          <a href="//twitter.com/googledevs"\n             class="devsite-footer-linkbox-link gc-analytics-event"\n             data-category="Site-Wide Custom Events"\n            \n             data-label="Footer Link (index 4)"\n            >\n          \n            Twitter\n          \n          </a>\n          \n        </li>\n        \n        <li class="devsite-footer-linkbox-item">\n          \n          <a href="//www.youtube.com/user/GoogleDevelopers"\n             class="devsit ...

# %%
import requests

r = requests.get('http://www.naver.com')
r.status_code
r.text
# Out:
# obile%2Fedit%2F2020%2F1125%2Fupload_222270913858680492Loi6.JPEG%22&amp;type&#x3D;nf340_228" alt="집들이까지 준비한 맞벌이 부부의 밥상 메뉴" width="170" height="114">\n\t\t\t\t\t\t<span class="thumb_bd"></span>\n\t\t\t\t\t</a>\n\t\t\t\t\t<a href="https://blog.naver.com/dmsqlc88/222148341592" class="theme_info" data-clk="tcc_fod.list12cont1" target="_blank">\n\t\t\t\t\t\t<em class="theme_category"> 푸드</em>\n\t\t\t\t\t\t<strong class="title elss">집들이까지 준비한 맞벌이 부부의 밥상 메뉴</strong>\n\t\t\t\t\t\t<p class="desc">\u200b\u200b맞벌이부부의 주간밥상* 주재료 : 굴, 부추, 당근, 무, 가지, 소고기, 버섯, 낙지, 굴, 해초, *예산 : 10만원요즘 불량주부로 지내고 있어 주간밥상 올리기가 참 부끄러워요 ;)늘 남편 아침으로 떡, 구운 계란, 바나나점심으로는 닭 가슴살 크랜베리 샌드위치를 챙겨주곤 했는데11월은 남편 점심 샌드위치를 챙겨주지 않아도 돼서 불량주부로 보내고 있답</p>\n\t\t\t\t\t\t<div class="source_box">\n\t\t\t\t\t\t\t<span class="date">2주일 전</span>\n\t\t\t\t\t\t\t<span class="source"><span class="source_inner">이오떼</span></span>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t</a>\n\t\t\t\t</li>\n\t\t\t\n\t\t\t\t<li class="theme_item" data-gdid="CAS_6dabafd7-2e33-11eb-b098-7b83428e84b2" data-da-position="true">\n\t\t\t\t\t<a href="https://blog.naver.com/dpwls9883/222145615781" class="theme_thumb" data-clk="tcc_fod.list12cont2" target="_blank">\n\t\t\t\t\t\t<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2020%2F1125%2Fupload_222270867069698043W84t.JPEG%22&amp;type&#x3D;nf340_228" alt="한 주 열심히 챙겨 먹은 신혼부부의 일상 밥상" width="170" height="114">\n\t\t\t\t\t\t<span class="thumb_bd"></span>\n\t\t\t\t\t</a>\n\t\t\t\t\t<a href="https://blog.naver.com/dpwls9883/222145615781" class="theme_info" data-clk="tcc_fod.list12cont2" target="_blank">\n\t\t\t\t\t\t<em class="theme_category"> 푸드</em>\n\t\t\t\t\t\t<strong class="title elss">한 주 열심히 챙겨 먹은 신혼부부의 일상 밥상</strong>\n\t\t\t\t\t\t<p class="desc">안녕하세요. 찌니에요 :)한 주도 알차게 잘 보내셨어요?저흰 열심히 챙겨먹으며 잘 보냈어요!맛있게 챙겨먹은 #일상밥상 포스팅 시작하도록하겠어요.\u200b#제철밥상 #알뜰밥상 #신혼부부밥상#일주일식단표 #일주일식단 #일주일밥상 #일주일반찬가족수 : 2인예산 : 6만원 미만주재료 : 참치, 삼겹살, 등뼈, 고형카레갈치, 당근, 김 등등11월 9일 월요일가볍게 한끼 때</p>\n\t\t\t\t\t\t<div class="source_box">\n\t\t\t\t\t\t\t<span class="date">2주일 전</span>\n\t\t\t\t\t\t\t<span class="source"><span class="source_inner">찌니</span></span>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t</a>\n\t\t\t\t</li>\n\t\t\t\n\t\t\t\t<li class="theme_item" data-gdid="CAS_3978f387-2e19-11eb-9aa9-e1efd7055ef0" data-da-position="true">\n\t\t\t\t\t<a href="https://blog.naver.com/hrc2020/222133621348" class="theme_thumb" data-clk="tcc_fod.list12cont3" target="_blank">\n\t\t\t\t\t\t<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2020%2F1125%2Fupload_22215962725230156tYc8A.jpg%22&amp;type&#x3D;nf340_228" alt="든든한 냉동식품과 과일을 담았어요" width="170" height="114">\n\t\t\t\t\t\t<span class="thumb_bd"></span>\n\t\t\t\t\t</a>\n\t\t\t\t\t<a href="https://blog.naver.com/hrc2020/222133621348" class="theme_info" data-clk="tcc_fod.list12cont3" target="_blank">\n\t\t\t\t\t\t<em class="theme_category"> 푸드</em>\n\t\t\t\t\t\t<strong class="title elss">든든한 냉동식품과 과일을 담았어요</strong>\n\t\t\t\t\t\t<p class="desc">\u200b하핫 장바구니 처음으로 공개해봐요저희는 한번에 왕창사는 스타일이 아니라찔꿈찔꿈 필요할 때마다 사먹는 스타일이라장바구니 공개가 쉽지 않을 것 같아요\u200b\u200b바나나를 엄청 좋아하는데요여름에는 바나나를 못먹어요초파리를 엄청엄청 싫어해서아예 걔네들이 좋아하는건 집에 안들여요 ㅋㅋ\u200b드디어 날씨가 추워져서 바나나를!쓱데이에 1+1이더라구요잽싸게 쟁여왔습니다 ♥...</p>\n\t\t\t\t\t\t<div class="source_box">\n\t\t\t\t\t\t\t<span class="date">1개월 전</span>\n\t\t\t\t\t\t\t<span class="source"><span class="source_inner">헬레나</span></span>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t</a>\n\t\t\t\t</li>\n\t\t\t\n\t\t\t\t<li class="theme_item" data-gdid="CAS_3978f385-2e19-11eb-9aa9-bd3d8306093f" data-da-position="true">\n\t\t\t\t\t<a href="https://blog.naver.com/guebyul/222073871141" class="theme_thumb" data-clk="tcc_fod.list12cont4" target="_blank">\n\t\t\t\t\t\t<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2020%2F1125%2Fupload_222159541438292863Lr9t.jpg%22&amp;type&#x3D;nf340_228" alt="아이와 집콕생활을 대비하는 ...

# %%
# !chcp 65001
# !dir
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\user\anaconda3\envs\ssac-first\lib\site-packages (2.25.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\ssac-first\lib\site-packages (from requests) (2020.11.8)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\user\anaconda3\envs\ssac-first\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\user\anaconda3\envs\ssac-first\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\envs\ssac-first\lib\site-packages (from requests) (1.26.2)

# %%
 # !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\user\anaconda3\envs\ssac-first\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\user\anaconda3\envs\ssac-first\lib\site-packages (from selenium) (1.26.2)

# %%
from selenium import webdriver

# %%
browser = \
webdriver.Chrome(executable_path=r "C:\Users\USER\Desktop\SSAC\python\chromedriver.exe")
# Out:
#   File "<ipython-input-72-5e45d919fa45>", line 2
#     webdriver.Chrome(executable_path=r "C:\Users\USER\Desktop\SSAC\python\chromedriver.exe")
#                                                                                           ^
# SyntaxError: invalid syntax

# %%
browser.get("http://python.org")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-d205d1be9bdc> in <module>
# ----> 1 browser.get("http://python.org")
#
# NameError: name 'browser' is not defined
